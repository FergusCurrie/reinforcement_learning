# %% [markdown]
# # Multiarmed bandit visual of convergence

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
from multi_armed_bandit import epsilon_greedy

# %%
total_reward, take_action = epsilon_greedy(k=10, epsilon=0.1, n_steps=1000)

# %% [markdown]
# ## Looking at reward

# %%
plt.plot(np.arange(len(total_reward)), np.cumsum(total_reward))
